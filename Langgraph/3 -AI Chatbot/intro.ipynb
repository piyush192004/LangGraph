# %% [markdown]
# ### Agenda :
# 1. Chatbot with Langgraph + Tools {Multiple Tools}
# 2. ReAct Architecture [Reasoning + Acting]

# %% [markdown]
# ## Workflow : [Chatbot Workflow]
#
# Start -> AI Assistant -> Tools -> Arxiv / Wikipedia Tool / Internet Search Tool -> Tools -> End
